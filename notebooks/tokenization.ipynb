# %%
from transformers import AutoTokenizer

text = "Tokenization is surprisingly powerful!"

models = {
    "BERT (WordPiece)": "bert-base-uncased",
    "GPT-2 (BPE)": "gpt2",
    "T5 (SentencePiece)": "t5-small"
}

for name, model in models.items():
    tokenizer = AutoTokenizer.from_pretrained(model)
    print("\n", name)
    print(tokenizer.tokenize(text))
# Out:
#  BERT (WordPiece)
# ['token', '##ization', 'is', 'surprisingly', 'powerful', '!']
#
#  GPT-2 (BPE)
# ['Token', 'ization', 'Ġis', 'Ġsurprisingly', 'Ġpowerful', '!']
#
#  T5 (SentencePiece)
# ['▁To', 'ken', 'ization', '▁is', '▁', 'surprisingly', '▁powerful', '!']
